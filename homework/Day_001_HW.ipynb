# %% [markdown]
# # 作業一
#
#  請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# <br>選擇資料：[Home Credit Default Risk](https://www.kaggle.com/c/home-credit-default-risk/overview)
# 1. 你選的這組資料為何重要：
# <br>    大數據時代來臨，除了讓人們享受更人性化的生活，也讓企業能用更科學化的方式提供服務，
# <br>但也同時讓消費者成為一連串沒感情的數字，在這情況之下，企業為了降低風險而拒絕這類帳面上不合格的消費者，這類人成為數位獨裁下的犧牲品，要怎麼避免這類事情是個大哉問，房屋信貸風險指數就是一個很好的研究議題。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# <br>On kaggle
#
# 3. 蒐集而來的資料型態為何
# <br>Too more.Including string,boolean,float,integer.
#
# 4. 這組資料想解決的問題如何評估
# <br>將信用評分,年齡,收入...等等因素建立一套演算法.
#
# # 作業二
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# <br>提升業績更應該注重於交易的量而非質，故要撇除對利潤的迷思，專注於提高載客率與降低空車率。
# <br>影響載客率與空車率重要因子來自:地點、時間，鎖定主要服務客群為何者?並且歸納出該族群容易出入的地點，以定點接客取代顧客隨機攔車，一方面降低無用的消耗外，更可以讓自由載客車隊形成品牌。
# <br>且配合一般人作息，需求量會有一個高峰期，瞄準高峰期吸引顧客，顧客相對少的時間讓司機有足夠私人時間。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# <br>運用手機APP蒐集顧客基本資料，乘車時間，起迄點等等資訊也十分重要
#
# 3. 蒐集而來的資料型態為何
# <br>叫車時機：date 乘車時間：date 起迄點：date
# <br>是否攜帶行李：boolean 乘客人數：int 付款方式：string
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# <br>利用叫車時機與起訖點可以先將客群分類，並得知何時何處屬於需求量高峰時機，拉高單位時間業績。
#
#
# # 作業三
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    """
    args
        - y:實際值
        - yp:預測值
    return:
        - mse:標準誤
    """
        
    mse=sum(y-y_hat)**2/len(y)
    return mse

# %%
def mean_absolute_error(y,y_hat):
    mae=sum(y-y_hat)/len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 91.735
# The Mean absolute error is -0.953
